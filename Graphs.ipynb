# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## INSERT

# %%
data_insert = pd.read_csv('insert.csv', sep=';').to_dict()

# %%
number_of_elements = list(data_insert['AVL'].keys())
AVL_insert_time = list(data_insert['AVL'].values())
# Splay_insert_time = list(data_insert['Splay'].values())
Cartesian_insert_time = list(data_insert['Cartesian'].values())
RedBlack_insert_time = list(data_insert['Red-Black'].values())
lg = [math.log(10*n) for n in number_of_elements]

# %%
plt.plot(number_of_elements, AVL_insert_time, label = "AVL")
# plt.plot(number_of_elements, Splay_insert_time, label = "Splay")
plt.plot(number_of_elements, Cartesian_insert_time, label = "Cartesian")
plt.plot(number_of_elements, RedBlack_insert_time, label = "RedBlack")
plt.plot(number_of_elements, lg, label="LOG")
plt.legend()

# %% [markdown]
# ## DELETE

# %%
data_delete = pd.read_csv('delete.csv', sep=';').to_dict()

# %%
number_of_elements = list(data_delete['AVL'].keys())
AVL_delete_time = list(data_delete['AVL'].values())
Splay_delete_time = list(data_delete['Splay'].values())
Cartesian_delete_time = list(data_delete['Cartesian'].values())
RedBlack_delete_time = list(data_delete['Red-Black'].values())
lg = [math.log(10*n) for n in number_of_elements]

# %%
plt.plot(number_of_elements, AVL_delete_time, label = "AVL")
plt.plot(number_of_elements, Splay_delete_time, label = "Splay")
plt.plot(number_of_elements, Cartesian_delete_time, label = "Cartesian")
plt.plot(number_of_elements, RedBlack_delete_time, label = "RedBlack")
plt.plot(number_of_elements, lg, label="LOG")
plt.legend()

# %% [markdown]
# ## SEARCH

# %%
data_search = pd.read_csv('search.csv', sep=';').to_dict()

# %%
number_of_elements = list(data_search['AVL'].keys())
AVL_search_time = list(data_search['AVL'].values())
Splay_search_time = list(data_search['Splay'].values())
Cartesian_search_time = list(data_search['Cartesian'].values())
RedBlack_search_time = list(data_search['Red-Black'].values())
# lg = [math.log(n) for n in number_of_elements]

# %%
plt.plot(number_of_elements, AVL_search_time, label = "AVL")
plt.plot(number_of_elements, Splay_search_time, label = "Splay")
plt.plot(number_of_elements, Cartesian_search_time, label = "Cartesian")
plt.plot(number_of_elements, RedBlack_search_time, label = "RedBlack")
# plt.plot(number_of_elements, lg, label="LOG")
plt.legend()
